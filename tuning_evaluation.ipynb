# %%
from pathlib import Path
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from tuning_studies.modelconfig import ModelConfig
from utils.tuning import combine_resfiles
import config

# %%
# Load split metadata
df_split_metadata = pd.read_csv(Path(config.output_dir_splits) / "split_metadata.csv")
df_split_metadata["split"] = df_split_metadata["filepath"].apply(lambda x: Path(x).stem)

# %% [markdown]
# # Evaluate validation RMSE and splitting schemes

# %%
# model_name = "mastnet"
# df = combine_resfiles(config.output_dir_tuning + model_name + "/architecture_ablation/exp54/", file_ending=".json", out_name=f"/{model_name}_tuning.csv", remove_files=False)
model_name = "remasker"
df = combine_resfiles(config.output_dir_tuning + model_name, file_ending=".json", out_name=f"/{model_name}_tuning.csv", remove_files=False)

df["total_time"] = df["train_time"] + df["pred_time"]
df = df.merge(df_split_metadata, on="split", how="left")

# %%
split_resolution_map = {"fold_block_0": "Block (5°)", "fold_block_15": "Block (15°)", "fold_block_30": "Block (40°)",
                        "fold_random_0": "Random (10%)", "fold_random_1": "Random (20%)"}
df["split_plot_name"] = df["split"].map(split_resolution_map)
df["scheme"] = df["scheme"].map({"random": "Random", "block": "Block"})
df = df.rename(columns={"scheme": "Scheme"})

# %%
print(
    f"{model_name}: Mean total time per model = {df.total_time.mean():.2f} s, mean validation RMSE per model = {df.val_rmse.mean():.5f} +- {df.val_rmse.std():.5f}")
print(f"{model_name}: Mean train time per model = {df.train_time.mean() / 60:.2f} min")

sns.boxplot(x=0, y=df["val_rmse"])
plt.ylabel("Validation RMSE")
plt.xticks(ticks=[0], labels=[f"{model_name} imputation"])
plt.show()

sns.boxplot(y=df["train_time"], x=0)
if df["pred_time"].any(): sns.boxplot(y=df["pred_time"], x=1)
plt.xticks(ticks=[0, 1], labels=["Train", "Predict"])
plt.ylabel("Time [s]")
plt.show()

plt.figure(figsize=(7, 5))
sns.boxplot(df, x="split_plot_name", y="val_rmse", hue="Scheme")  #, size="val_size")
# plt.xticks(ticks=df["split_plot_name"], labels=df["filepath"].astype("category").cat.codes)
# plt.xticks(ticks=df["split_plot_name"], labels=df["split_plot_name"])
plt.ylabel("Validation RMSE")
plt.xlabel("Splitting scheme")
plt.savefig(f"{config.output_dir_high_res_plots}/validation_rmse_over splits_" + model_name + ".png", dpi=1000)
plt.show()

# %%
df[["val_rmse", "train_time", "pred_time", "val_size"]].corr()

# %%
if model_name == "mean":
    df_mean = df[df["hyps"].apply(lambda x: x.get("strategy") == "mean")]
    df_median = df[df["hyps"].apply(lambda x: x.get("strategy") == "median")]
    print("Difference in RMSE between mean and median imputation: ",
          df_mean.val_rmse.mean() - df_median.val_rmse.mean())

# %% [markdown]
# # Optuna evaluation

# %%
import optuna
from optuna.visualization import plot_optimization_history, plot_param_importances, plot_slice, plot_contour
from optuna.trial import TrialState

from utils.tuning import load_optuna_study

#model_name = "remasker"

# Load Optuna study
study = load_optuna_study(model_name)

# %%
best_params = study.best_trial.params
print("Hyperparameters: ", best_params)
print("Validation loss: ", study.best_trial.value)
print("Duration: ", study.best_trial.duration)
print(study.best_trial)

# %%
# Incomplete trials
incomplete_trials = []
for trial in study.trials:
    if trial.state != TrialState.COMPLETE:
        # print(trial.number)
        # print(trial.params)
        incomplete_trials.append(trial)

print("Number of incomplete trials: ", len(incomplete_trials))

# %%
len(study.trials)

# %%
trial_times = [trial.value for trial in study.trials if trial.value is not None]
plt.figure(figsize=(6, 4))
plt.boxplot(trial_times, vert=True, patch_artist=True)
plt.ylabel("Validation RMSE per trial")
plt.title("Optuna Trial RMSE")
plt.show()

# %%
trial_times = [trial.duration.total_seconds() for trial in study.trials if trial.duration is not None]
plt.figure(figsize=(6, 4))
plt.boxplot(trial_times, vert=True, patch_artist=True)
plt.ylabel("Trial Time (seconds)")
plt.title("Optuna Trial Times")
plt.show()

# %%
# Feature importances
optuna.importance.get_param_importances(study)

# %%
# Set running trials to FAIL
# study._storage.remove_running_trials(study._study_id)

# %%
invalid_durations = pd.DataFrame(columns=["trial", "fold"])

durations = [
    {
        "trial": x.number,
        "duration": x.duration.seconds / 60 if x is not None and x.duration is not None and x.number not in list(
            invalid_durations.trial) else None
    }
    for x in study.trials
]
durations = pd.DataFrame(durations)

sns.lineplot(durations, x="trial", y="duration")

# %%
plot_optimization_history(study)

# %%
plot_param_importances(study)

# %%
plot_slice(study)

# %%
# target_dpi = 1000
#
# fig_contour = plot_contour(study)
# if model_name == "mice":
#     fig_contour.update_layout(width=600, height=600)
# elif model_name == "knn":
#     fig_contour.update_layout(width=800, height=600)
# elif model_name == "mae" or model_name == "mae_finetune" or model_name == "mastnet" or model_name == "mlp" or model_name == "remasker":
#     fig_contour.update_layout(width=1200, height=1600)
# else:
#     fig_contour.update_layout(width=600, height=800)
# fig_contour.update_layout(title=None)
# fig_contour.write_image(f"output/high_res_plots/contour_{model_name}.png", scale=target_dpi / 96)
# fig_contour.show()

# %%
# Mean and std of RMSE across trials
values = [t.value for t in study.get_trials() if t.state == optuna.trial.TrialState.COMPLETE]
df_rmse = pd.DataFrame(values, columns=["rmse"])
mean_error = df_rmse["rmse"].mean()
std_error = df_rmse["rmse"].std()

print("Mean:", mean_error)
print("Std:", std_error)

# %% [markdown]
# # Train model on best hyperparameter combination

# %%
import json
import numpy as np
from sklearn.base import BaseEstimator
import torch
import pandas as pd
import types
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, root_mean_squared_error

from tuning_studies.sklearn_study import train_sklearn_single_split
from tuning_studies.pytorch_study import train_pytorch_single_split
from utils.tuning import set_seed, TuningResult, get_model_class, load_optuna_study
from nn_utils.dataset import load_dataset
from utils.plotting import generate_animation
import config
# Out:
# C:\Users\yvjennig\Anaconda3\envs\time_imputation\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# C:\Users\yvjennig\Anaconda3\envs\time_imputation\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# ...

# %%
# Load test-train split
split = json.load(open(f"{config.output_dir_splits}/test_train_split.json"))
test_idx = np.array(split["test_idx"], dtype=int)
train_idx = np.array(split["train_idx"], dtype=int)

# Load dataset
df = load_dataset()

# Load study
model_name = "remasker"
model_class = get_model_class(model_name)
study = load_optuna_study(model_name)
hyps = study.best_trial.params

# Set seed
seed = 42
generator = set_seed(seed=seed)
# Out:
# Study loaded as log

# %%
from tuning_studies import modelconfig
model_name = "mastnet"
model_class = get_model_class(model_name)
cfg = modelconfig.ablation_study["exp73"]["config"]

hyps = {"train": {
                "n_neighbours": cfg.n_neighbours,
                "batch_size": 128,
                "learning_rate": 1e-4,
                "patience": 10,
                "n_epochs": 100,
                "mask_ratio": cfg.mask_ratio,
                "loss": cfg.loss_name,
                "optimizer": torch.optim.Adam
            },
            "model": {
                "d_model": 64,
                "nhead": 4,
                "nlayers": 3,
                "dim_feedforward": 256,
                "dropout": 0.05
            }
        }

# %%
# hyps = {'n_estimators': 70, 'max_depth': 20, 'bootstrap': True}

# %%
# hyps = {
#     "n_neighbours": 32,
#     "batch_size": 128,
#     "lr": 3e-4,
#     "mask_ratio": 0.2,
#
#     "d_model": 64,
#     "nhead": 4,
#     "nlayers": 2,
#     "dim_feedforward": 128,
#     "dropout": 0.15
# }

# %%
# hyps={'loss': 'hetero',
#  'n_neighbours': 28,
#  'batch_size': 128,
#  'lr': 0.00020914997843645634,
#  'mask_ratio': 0.04825988173493892,
#  'd_model': 64,
#  'nhead': 4,
#  'nlayers': 3,
#  'dim_feedforward': 512,
#  'dropout': 0.0600946692200131}

# %%
# Assemble hyps for mae
if model_name == "mastnet":
    hyps = {"train": {
        "n_neighbours": hyps["n_neighbours"],
        "batch_size": hyps["batch_size"],
        "learning_rate": hyps["lr"],
        "patience": 10,
        "n_epochs": 6, #00,
        "mask_ratio": hyps["mask_ratio"],
        "loss": "mse", #hyps["loss"],
        "optimizer": torch.optim.Adam
    },
        "model": {
            "d_model": hyps["d_model"],
            "nhead": hyps["nhead"],
            "nlayers": hyps["nlayers"],
            "dim_feedforward": hyps["dim_feedforward"],
            "dropout": hyps["dropout"],
        }
    }

elif model_name == "mlp":
    hyps = {"train": {
        "batch_size": hyps["batch_size"],
        "learning_rate": hyps["lr"],
        "patience": 15,
        "n_epochs": 200,
        "mask_ratio": hyps["mask_ratio"],
        "loss": hyps["loss"],
        "optimizer": torch.optim.Adam
    },
        "model": {
            "hidden_dims": hyps["hidden_dims"],
            "dropout": hyps["dropout"]
        }
    }

elif model_name == "remasker":
    hyps["max_epochs"] = 200

# %%
from tuning_studies.modelconfig import ablation_study
cfg = ablation_study["exp0"]["config"]

# %%
hyps
# Out:
# {'embed_dim': 64,
#  'num_heads': 4,
#  'batch_size': 128,
#  'mask_ratio': 0.5168133396088784,
#  'depth': 2,
#  'decoder_depth': 5,
#  'encode_func': 'linear',
#  'max_epochs': 200}

# %%
variance = None
i = 0

if isinstance(model_class, types.FunctionType) or issubclass(model_class, BaseEstimator) or model_name == "remasker":
    if isinstance(model_class, types.FunctionType):
        save_model = False
    else:
        save_model = True

    print("Sklearn model...")
    results, y_true, y_pred, scaler_dict = train_sklearn_single_split(
        df=df,
        model_class=model_class,
        hyps=hyps,
        test_idx=test_idx,
        train_idx=train_idx,
        val_idx=test_idx,
        model_name=model_name,
        split_path="final",
        trial_id=i,
        optuna_callback=None,
        seed=seed + i,
        tuning_mode=False,
        save_model=save_model,
        output_dir=f"output/testing/{model_name}/",
    )

elif issubclass(model_class, torch.nn.Module):
    print("PyTorch model...")
    results, y_true, y_pred, variance, scaler_dict = train_pytorch_single_split(
        coords_raw=torch.tensor(df[config.coordinates].astype(float).to_numpy()),
        values_raw=torch.tensor(df[config.parameters].astype(float).to_numpy()),
        model_class=model_class,
        hyps=hyps,
        train_idx=train_idx,
        val_idx=test_idx,
        test_idx=test_idx,
        model_name=model_name,
        split_path="final",
        trial_id=i,
        optuna_callback=None,
        seed=seed + i,
        tuning_mode=False,
        device=torch.device("cuda"),
        do_dropout=True,
        n_inferences=50,  # 50
        save_model=True,
        cfg=cfg,
        output_dir=f"output/testing/{model_name}/",  # f"output/testing/{model_name}/exp56/",
    )

else:
    print(f"Unknown model type: {model_class}")
# Out:
# Sklearn model...
# Using device:  cuda
# Training:   4%|▎         | 7/200 [16:39<7:39:10, 142.75s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 11
#       8         save_model = True
#      10     print("Sklearn model...")
# ---> 11     results, y_true, y_pred, scaler_dict = train_sklearn_single_split(
#      12         df=df,
#      13         model_class=model_class,
#      14         hyps=hyps,
#      15         test_idx=test_idx,
#      16         train_idx=train_idx,
#      17         val_idx=test_idx,
#      18         model_name=model_name,
#      19         split_path="final",
#      20         trial_id=i,
#      21         optuna_callback=None,
#      22         seed=seed + i,
#      23         tuning_mode=False,
#      24         save_model=save_model,
#      25         output_dir=f"output/testing/{model_name}/",
#      26     )
# ...

# %%
results
# Out:
# TuningResult(split='final', seed=42, model='mastnet', hyp_combo_id=0, hyps={'train': {'n_neighbours': 30, 'batch_size': 128, 'learning_rate': 0.0001, 'patience': 10, 'n_epochs': 100, 'mask_ratio': 0.3, 'loss': 'hetero', 'optimizer': <class 'torch.optim.adam.Adam'>}, 'model': {'d_model': 64, 'nhead': 4, 'nlayers': 3, 'dim_feedforward': 256, 'dropout': 0.05, 'global_means': tensor([0.3544, 0.8833, 0.5120, 0.0398, 0.0446, 0.0400]), 'cfg': ModelConfig(graph_mode='static', graph_space='raw', graph_metric='isotropic', encoder_scope='none', encoder_input='coords', encoder_output_dim=3, encoder_hidden_dim=64, fill_strategy='zero', feature_mixer=True, feature_mixer_input='feat', use_rel_pos=False, use_masks=True, attention_type='space_time_attention', masking_strategies=None, block_mask_size=0.1, block_mask_p=0.3, line_mask_width=0.05, line_mask_p=0.3, mask_ratio=0.3, n_neighbours=30, graph_update_frequency=5, graph_warmup=0, graph_freeze_epoch=20, learn_anisotropic_weights=False, positional_
# ...

# %%
# Store y_pred and y_true
if y_pred.shape[1] == 11:
    coord_dim = 5
    y_pred = y_pred[:, coord_dim:]

df_pred = pd.DataFrame(y_pred, columns=config.parameters)
df_pred.to_csv(f"output/testing/{model_name}/model{model_name}_y_pred.csv")
pd.DataFrame(y_true, columns=config.parameters).to_csv(f"output/testing/{model_name}/model{model_name}_y_true.csv")

# %%
# Imputation (replace nan values with predictions)
df_imputed = pd.DataFrame(y_true, columns=config.parameters)
df_imputed = df_imputed.combine_first(pd.DataFrame(y_pred, columns=config.parameters))
df_imputed[config.coordinates] = df[config.coordinates]

for param in config.parameters:
    generate_animation(df_imputed, scaler_dict=scaler_dict, parameter=param,
                   save_as=f"output/testing/{model_name}/model{model_name}_{param}_imputation_{model_name}.mp4")

    # Reconstruction
    if model_name == "mastnet" or model_name == "remasker":
        df_rec = pd.DataFrame(y_pred, columns=config.parameters)
        df_rec[config.coordinates] = df[config.coordinates]
        generate_animation(df_rec, scaler_dict=scaler_dict, parameter=param,
                           save_as=f"output/testing/{model_name}/model{model_name}_{param}_reconstruction_{model_name}.mp4")

    if variance is not None:
        df_variance = pd.DataFrame(variance[0], columns=config.parameters)
        df_variance[config.coordinates] = df[config.coordinates]
        generate_animation(df_variance, scaler_dict=None, parameter=param,
                           save_as=f"output/testing/{model_name}/model{model_name}_{param}_aleatoric_{model_name}.mp4")

        df_variance = pd.DataFrame(variance[1], columns=config.parameters)
        df_variance[config.coordinates] = df[config.coordinates]
        generate_animation(df_variance, scaler_dict=None, parameter=param,
                           save_as=f"output/testing/{model_name}/model{model_name}_{param}_epistemic_{model_name}.mp4")
# Out:
# Animation saved as output/testing/mastnet/modelmastnet_P_TEMPERATURE_imputation_mastnet.mp4
# Animation saved as output/testing/mastnet/modelmastnet_P_TEMPERATURE_reconstruction_mastnet.mp4
# Animation saved as output/testing/mastnet/modelmastnet_P_TEMPERATURE_aleatoric_mastnet.mp4
# Animation saved as output/testing/mastnet/modelmastnet_P_TEMPERATURE_epistemic_mastnet.mp4
# Animation saved as output/testing/mastnet/modelmastnet_P_SALINITY_imputation_mastnet.mp4
# Animation saved as output/testing/mastnet/modelmastnet_P_SALINITY_reconstruction_mastnet.mp4
# Animation saved as output/testing/mastnet/modelmastnet_P_SALINITY_aleatoric_mastnet.mp4
# Animation saved as output/testing/mastnet/modelmastnet_P_SALINITY_epistemic_mastnet.mp4
# Animation saved as output/testing/mastnet/modelmastnet_P_OXYGEN_imputation_mastnet.mp4
# Animation saved as output/testing/mastnet/modelmastnet_P_OXYGEN_reconstruction_mastnet.mp4
# ...
